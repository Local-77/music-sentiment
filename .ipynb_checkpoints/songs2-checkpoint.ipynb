# %%
import pandas as pd
from pathlib import Path

# %%
df = pd.read_csv('output.csv')

print(df.head())
# Out:
#                title  tag     artist  year   views  \
# 0          Killa Cam  rap    Cam'ron  2004  173166
# 1         Can I Live  rap      JAY-Z  1996  468624
# 2  Forgive Me Father  rap   Fabolous  2003    4743
# 3       Down and Out  rap    Cam'ron  2004  144404
# 4             Fly In  rap  Lil Wayne  2005   78271
#
#                                               lyrics  Positive  Negative  \
# 0  [Chorus: Opera Steve & Cam'ron]\nKilla Cam, Ki...  0.268202  0.620502
# 1  [Produced by Irv Gotti]\n\n[Intro]\nYeah, hah,...  0.158539  0.744684
# 2  Maybe cause I'm eatin\nAnd these bastards fien...  0.221860  0.653244
# 3  [Produced by Kanye West and Brian Miller]\n\n[...  0.182553  0.719833
# 4  [Intro]\nSo they ask me\n"Young boy\nWhat you ...  0.113128  0.767366
#
#     Neutral
# 0  0.111296
# 1  0.096777
# 2  0.124896
# 3  0.097614
# 4  0.119506

# %%
sorted_df = df.sort_values(by=['Positive', 'view'' ascending=False)

# %%
sorted_df.to_csv("output.csv")
# Out:
#                                     title   tag                 artist  year  \
# 245433                          Super gut   pop                   Modo  1995
# 375531                              Waves   pop                Tourist  2016
# 275123                          Love Inc.   pop            Booka Shade  2013
# 456739                     Valentines Day  misc             Klaus Nomi  2007
# 261650  All Creatures of Our God and King   pop     David Crowder Band  2002
# ...                                   ...   ...                    ...   ...
# 476441                          So I Sing   pop             Mosaic MSC  2017
# 206956                      Wonderful God   pop       Hillsong Worship  2005
# 307940                 You Got To Love Me   pop           David August  2011
# 307659                  God Is A Good God   pop  Bishop Paul S. Morton  2003
# 612541                   La Vie Est Belle   pop           La Belle Vie  2018
#
# ...
