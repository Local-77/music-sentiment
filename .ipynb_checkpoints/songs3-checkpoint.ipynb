# %%
import pandas as pd
from pathlib import Path

# %%
df = pd.read_csv('output.csv')

print(df.head())
# Out:
#    Unnamed: 0                              title   tag              artist  \
# 0      245433                          Super gut   pop                Modo
# 1      375531                              Waves   pop             Tourist
# 2      275123                          Love Inc.   pop         Booka Shade
# 3      456739                     Valentines Day  misc          Klaus Nomi
# 4      261650  All Creatures of Our God and King   pop  David Crowder Band
#
#    year  views                                             lyrics  Positive  \
# 0  1995   2837  Gut, gut, super gut!\nGut, gut, super gut!\nGu...  0.994537
# 1  2016   1239  [Verse 1]\nI'll be happy to do make you happy\...  0.993658
# 2  2013   2775  Love is when you feel like\nWhen you feel good...  0.993209
# 3  2007   1438  Thank you!\nYou're very welcome!\nOh yes I kno...  0.992459
# 4  2002   4223  All creatures of our God and King\nLift up you...  0.992129
#
#    Negative   Neutral
# 0  0.001354  0.004109
# 1  0.001455  0.004888
# 2  0.001943  0.004847
# 3  0.001870  0.005671
# 4  0.003283  0.004588

# %%
sorted_df = df.sort_values(by='Positive', ascending=False)

# %%
high_views_df = sorted_df[sorted_df['views'] >= 700000]
high_views_df[(high_views_df['Negative'] > 0.70) & (high_views_df['Positive'] <= 0.30)].sort_values(by='Negative', ascending=False).head(20)
# Out:
#         Unnamed: 0                                 title   tag  \
# 839131      280581                                  Riot   rap
# 838400       89695                               Bad Guy   rap
# 837074      374992                               Amnésie   rap
# 838827      434343                                BLOOD.   rap
# 835129       89698                        So Much Better   rap
# 835710        5358               They Dont Care About Us   pop
# 832235      621806                                 Au DD   rap
# 827050         915                              I’m Back   rap
# 826956      465263                          Heyecanı Yok   rap
# 821607      391332                                  STFU   rap
# 833055      368355                                OOOUUU   rap
# 826798      607033                           Shotta Flow   rap
# 833332      169682                I Took a Pill in Ibiza   pop
# 826856      458729                              Betrayed   rap
# 822399      795680                               ​brutal  rock
# 836196      451924  XXL Freshman Freestyle: XXXTENTACION   rap
# 823476      340779                        All My Friends    rb
# 829185      511713                                 BILLY   rap
# 829782       37298                           Dont Like.1   rap
# 826051          63                               A Milli   rap
#
#                                                    artist  year    views  \
# 839131                                       XXXTENTACION  2015  1322131
# 838400                                             Eminem  2013  2101460
# 837074                                              Damso  2016   981855
# 838827                                     Kendrick Lamar  2017  1128496
# 835129                                             Eminem  2013   835877
# 835710                                    Michael Jackson  1995   993938
# 832235                                                PNL  2019  1270655
# 827050                                             Eminem  2000   851582
# 826956                                           Gazapizm  2017  1031608
# 821607                                           Pink Guy  2016   995790
# 833055                                          Young M.A  2016  3765758
# 826798                                         NLE Choppa  2019  1349632
# 833332                                        Mike Posner  2015  1748799
# 826856                                            Lil Xan  2017  1863814
# 822399                                     Olivia Rodrigo  2021   910305
# 836196                                                XXL  2017   769502
# 823476                                          Snakehips  2015   957637
# 829185                                            6ix9ine  2018  1315432
# 829782  Kanye West, Chief Keef, Pusha T, Big Sean & Ja...  2012  2239173
# 826051                                          Lil Wayne  2008  1237174
#
#                                                    lyrics  Positive  Negative  \
# 839131  [Intro]\n(Luke White on the beat)\n\n[Verse]\n...  0.028778  0.939290
# 838400  Part 1: Produced by S1 and M-Phazes\n\n[Verse ...  0.034352  0.935008
# 837074  [Paroles de "Amnésie"]\n\n[Couplet 1]\nMort es...  0.040121  0.920728
# 838827  [Intro: Bēkon]\nIs it wickedness?\nIs it weakn...  0.031334  0.920159
# 835129  [Intro]\nYou fuckin' groupie\nPick up the godd...  0.046036  0.913969
# 835710  [Intro]\nAll I want to say is that they don't ...  0.044388  0.906822
# 832235  [Paroles de "Au DD"]\n\n[Couplet 1 : Ademo]\nB...  0.052074  0.898983
# 827050  [Chorus]\nThat's why they call me Slim Shady (...  0.060073  0.895296
# 826956  [''Heyecanı Yok'' için şarkı sözleri]\n\n[Naka...  0.060200  0.890349
# 821607  [Chorus]\nShut the fuck up\nYou're a fucking c...  0.066588  0.890288
# 833055  [Intro]\nYo, bro, I think I had too much Henne...  0.050519  0.886988
# 826798  [Intro]\nI wish everything I touch would turn ...  0.060404  0.885782
# 833332  [Verse 1]\nI took a pill in Ibiza to show Avic...  0.049931  0.885741
# 826856  [Intro]\nHuh, ayy (Yeah)\nYou are now listenin...  0.060317  0.885482
# 822399  [Intro]\nI want it to be, like, messy\n\n[Vers...  0.065736  0.885346
# 836196  [Verse]\nAnd hell is just a government creatio...  0.042945  0.884678
# 823476  [Intro: Tinashe]\nUh-huh, hoo\n\n[Verse 1: Tin...  0.064524  0.884497
# 829185  [Intro: Shotti & 6ix9ine]\nThat's my word, get...  0.057145  0.884424
# 829782  [Produced by Young Chop; co-production by Kany...  0.056229  0.883494
# 826051  [Intro]\nBangladesh\nYoung Money!\nYou dig?\nM...  0.061339  0.878800
#
#          Neutral
# 839131  0.031932
# 838400  0.030640
# 837074  0.039151
# 838827  0.048506
# 835129  0.039994
# 835710  0.048791
# 832235  0.048943
# 827050  0.044631
# 826956  0.049451
# 821607  0.043124
# 833055  0.062493
# 826798  0.053814
# 833332  0.064328
# 826856  0.054202
# 822399  0.048919
# 836196  0.072377
# 823476  0.050980
# 829185  0.058431
# 829782  0.060276
# 826051  0.059862

# %%
sentiment_by_year_df = df.groupby('year').agg({"Positive":"mean", "Negative":"mean", "Neutral":"mean"})

# %%
sentiment_by_year_df.loc[sentiment_by_year_df.index > 1930].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
sentiment_by_year_df = df.groupby('year').agg({"Positive":"mean", "Negative":"mean"})
sentiment_by_year_df.loc[sentiment_by_year_df.index > 1930].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
import matplotlib.pyplot as plt

post_1930 = df[df['year'] >= 1930]
sentiment_by_year_tag = df.groupby(['year', 'tag']).agg({"Positive":"mean", "Negative":"mean"}).reset_index()
pivot_positive = sentiment_by_year_tag.pivot(index='year', columns='tag', values='Positive')
pivot_positive.plot(title='Positive Sentiment Trends Over Years by Tag')
pivot_negative = sentiment_by_year_tag.pivot(index='year', columns='tag', values='Negative')
pivot_negative.plot(title='Negative Sentiment Trends Over Years by Tag')
plt.show()

# %%
sentiment_by_year_df = df.groupby('year').agg({"Positive":"mean", "Negative":"mean"})
sentiment_by_year_df.loc[sentiment_by_year_df.index > 1930].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 2
#       1 sentiment_by_year_df = df.groupby('tag').agg({"Positive":"mean", "Negative":"mean"})
# ----> 2 sentiment_by_year_df.loc[sentiment_by_year_df.index > 1930].plot()
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:58, in OpsMixin.__gt__(self, other)
#      56 @unpack_zerodim_and_defer("__gt__")
#      57 def __gt__(self, other):
# ---> 58     return self._cmp_method(other, operator.gt)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6980, in Index._cmp_method(self, other, op)
#    6977 elif is_object_dtype(self.dtype) and not isinstance(self, ABCMultiIndex):
#    6978     # don't pass MultiIndex
#    6979     with np.errstate(all="ignore"):
# -> 6980         result = ops.comp_method_OBJECT_ARRAY(op, self._values, other)
#    6982 else:
#    6983     with np.errstate(all="ignore"):
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:75, in comp_method_OBJECT_ARRAY(op, x, y)
#      73     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      74 else:
# ---> 75     result = libops.scalar_compare(x.ravel(), y, op)
#      76 return result.reshape(x.shape)
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'
